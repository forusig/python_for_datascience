# %% [markdown]
# <a href="https://colab.research.google.com/github/forusig/python_for_datascience/blob/main/TugasPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/project-cakap/toyota.csv')
data
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0               GT86  2016  16000       Manual    24089   Petrol  265  36.2
# 1               GT86  2017  15995       Manual    18615   Petrol  145  36.2
# 2               GT86  2015  13998       Manual    27469   Petrol  265  36.2
# 3               GT86  2017  18998       Manual    14736   Petrol  150  36.2
# 4               GT86  2017  17498       Manual    36284   Petrol  145  36.2
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 6733              IQ  2011   5500    Automatic    30000   Petrol   20  58.9
# 6734   Urban Cruiser  2011   4985       Manual    36154   Petrol  125  50.4
# 6735   Urban Cruiser  2012   4995       Manual    46000   Diesel  125  57.6
# 6736   Urban Cruiser  2011   3995       Manual    60700   Petrol  125  50.4
# 6737   Urban Cruiser  2011   4495       Manual    45128   Petrol  125  50.4
#
#       engineSize
# 0            2.0
# 1            2.0
# ...

# %%
print(data.shape)
# Out:
# (6738, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6738 entries, 0 to 6737
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         6738 non-null   object
#  1   year          6738 non-null   int64
#  2   price         6738 non-null   int64
#  3   transmission  6738 non-null   object
#  4   mileage       6738 non-null   int64
#  5   fuelType      6738 non-null   object
#  6   tax           6738 non-null   int64
#  7   mpg           6738 non-null   float64
#  8   engineSize    6738 non-null   float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 473.9+ KB

# %%
data.head(15)
# Out:
#     model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
# 1    GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0
# 2    GT86  2015  13998       Manual    27469   Petrol  265  36.2         2.0
# 3    GT86  2017  18998       Manual    14736   Petrol  150  36.2         2.0
# 4    GT86  2017  17498       Manual    36284   Petrol  145  36.2         2.0
# 5    GT86  2017  15998       Manual    26919   Petrol  260  36.2         2.0
# 6    GT86  2017  18522       Manual    10456   Petrol  145  36.2         2.0
# 7    GT86  2017  18995       Manual    12340   Petrol  145  36.2         2.0
# 8    GT86  2020  27998       Manual      516   Petrol  150  33.2         2.0
# 9    GT86  2016  13990       Manual    37999   Petrol  265  36.2         2.0
# 10   GT86  2013  10495       Manual    72000   Petrol  265  36.2         2.0
# ...

# %%
data.tail(15)
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 6723         Verso-S  2013   6995       Manual    33900   Petrol  125  51.4
# 6724         Verso-S  2011   4450       Manual    73000   Petrol  125  51.4
# 6725         Verso-S  2012   5795    Automatic    61237   Petrol   30  54.3
# 6726              IQ  2009   3995    Automatic    27292   Petrol   20  60.1
# 6727              IQ  2009   3495       Manual    43000   Petrol    0  65.7
# 6728              IQ  2009   2699       Manual    74095   Petrol    0  65.7
# 6729              IQ  2013   4950       Manual    72913   Petrol   30  54.3
# 6730              IQ  2013   4849       Manual    41142   Petrol    0  64.2
# 6731              IQ  2011   5995    Automatic    29000   Petrol   20  58.9
# 6732              IQ  2012   2495       Manual    72498   Petrol    0  64.2
# 6733              IQ  2011   5500    Automatic    30000   Petrol   20  58.9
# ...

# %%
data.describe()
# Out:
#               year         price        mileage          tax          mpg  \
# count  6738.000000   6738.000000    6738.000000  6738.000000  6738.000000
# mean   2016.748145  12522.391066   22857.413921    94.697240    63.042223
# std       2.204062   6345.017587   19125.464147    73.880776    15.836710
# min    1998.000000    850.000000       2.000000     0.000000     2.800000
# 25%    2016.000000   8290.000000    9446.000000     0.000000    55.400000
# 50%    2017.000000  10795.000000   18513.000000   135.000000    62.800000
# 75%    2018.000000  14995.000000   31063.750000   145.000000    69.000000
# max    2020.000000  59995.000000  174419.000000   565.000000   235.000000
#
#         engineSize
# count  6738.000000
# mean      1.471297
# std       0.436159
# min       0.000000
# 25%       1.000000
# 50%       1.500000
# 75%       1.800000
# max       4.500000

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6733    False
# 6734    False
# 6735    False
# 6736    False
# 6737    False
# Length: 6738, dtype: bool

# %%
data.drop_duplicates()
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0               GT86  2016  16000       Manual    24089   Petrol  265  36.2
# 1               GT86  2017  15995       Manual    18615   Petrol  145  36.2
# 2               GT86  2015  13998       Manual    27469   Petrol  265  36.2
# 3               GT86  2017  18998       Manual    14736   Petrol  150  36.2
# 4               GT86  2017  17498       Manual    36284   Petrol  145  36.2
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 6733              IQ  2011   5500    Automatic    30000   Petrol   20  58.9
# 6734   Urban Cruiser  2011   4985       Manual    36154   Petrol  125  50.4
# 6735   Urban Cruiser  2012   4995       Manual    46000   Diesel  125  57.6
# 6736   Urban Cruiser  2011   3995       Manual    60700   Petrol  125  50.4
# 6737   Urban Cruiser  2011   4495       Manual    45128   Petrol  125  50.4
#
#       engineSize
# 0            2.0
# 1            2.0
# ...

# %%
filter = data[(data.year > 2019) & (data.fuelType == 'Petrol')]
filter
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 8      GT86  2020  27998       Manual      516   Petrol  150  33.2         2.0
# 20     GT86  2020  26995    Semi-Auto     1500   Petrol  145  32.8         2.0
# 25     GT86  2020  31000       Manual     3000   Petrol  145  33.2         2.0
# 28     GT86  2020  24990       Manual      339   Petrol  145  33.2         2.0
# 50     GT86  2020  29769       Manual      999   Petrol  145  33.2         2.0
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 5520   Aygo  2020  12500       Manual      616   Petrol  145  57.7         1.0
# 5536   Aygo  2020   9995       Manual      649   Petrol  145  56.5         1.0
# 5538   Aygo  2020  11360       Manual      560   Petrol  145  57.7         1.0
# 5563   Aygo  2020  11500       Manual      472   Petrol  145  56.5         1.0
# 5980   C-HR  2020  25295    Automatic      219   Petrol  145  34.5         1.2
#
# [64 rows x 9 columns]

# %%
filter1 = data[(data.year > 2019) & (data.fuelType == 'Diesel')]
filter1
# Out:
#               model  year  price transmission  mileage fuelType  tax   mpg  \
# 6562          Hilux  2020  18495       Manual       50   Diesel  260   2.8
# 6563          Hilux  2020  23495       Manual      100   Diesel  260   2.8
# 6594          Hilux  2020  39257    Automatic     1259   Diesel  265   2.8
# 6596          Hilux  2020  30500    Automatic     5000   Diesel  260   2.8
# 6617          Hilux  2020  36995    Automatic      150   Diesel  260   2.8
# 6646   PROACE VERSO  2020  37950    Automatic     1000   Diesel  145  38.7
# 6648   PROACE VERSO  2020  47990    Automatic     1255   Diesel  145  38.7
# 6651   Land Cruiser  2020  44995    Semi-Auto      200   Diesel  150  30.1
# 6661   Land Cruiser  2020  50995    Semi-Auto     3390   Diesel  145  30.1
# 6672   Land Cruiser  2020  52291    Semi-Auto     3104   Diesel  145  30.1
# 6682   Land Cruiser  2020  50995    Automatic     3500   Diesel  145  30.1
# ...

# %%
data.nlargest(5, 'price')
# Out:
#               model  year  price transmission  mileage fuelType  tax   mpg  \
# 6711          Supra  2019  59995    Automatic     9909    Other  150  34.5
# 6670   Land Cruiser  2019  54991    Semi-Auto     1000   Diesel  145  30.1
# 6695   Land Cruiser  2020  54550    Automatic     4000   Diesel  150  30.1
# 6688   Land Cruiser  2020  52990    Automatic     1244   Diesel  145  30.1
# 6672   Land Cruiser  2020  52291    Semi-Auto     3104   Diesel  145  30.1
#
#       engineSize
# 6711         3.0
# 6670         2.8
# 6695         2.8
# 6688         2.8
# 6672         2.8

# %%
data.nsmallest(5, 'price')
# Out:
#          model  year  price transmission  mileage fuelType  tax   mpg  \
# 6427   Avensis  2003    850       Manual   167054   Diesel  205  48.7
# 289    Corolla  2001    899    Automatic    76000   Petrol  300  35.3
# 2447     Yaris  2002    950       Manual   104000   Petrol  200  40.4
# 2635     Yaris  2003    975       Manual   107000   Petrol  145  50.4
# 6431   Avensis  2007   1200    Automatic   120000   Petrol  300  36.7
#
#       engineSize
# 6427         2.0
# 289          1.6
# 2447         1.5
# 2635         1.0
# 6431         1.8

# %%
data.groupby(['year', 'transmission']).count()[['model']]
# Out:
#                    model
# year transmission
# 1998 Manual            1
# 1999 Automatic         1
# 2000 Automatic         1
# 2001 Automatic         1
# 2002 Automatic         2
#      Manual            2
# 2003 Automatic         2
#      Manual            4
# 2004 Automatic         5
#      Manual            2
# 2005 Automatic         1
#      Manual           11
# 2006 Automatic         2
#      Manual            9
# 2007 Automatic         5
#      Manual           15
# 2008 Automatic         7
#      Manual           11
#      Semi-Auto         1
# 2009 Automatic         7
#      Manual           20
#      Semi-Auto         2
# 2010 Automatic         6
#      Manual           11
#      Semi-Auto         1
# 2011 Automatic        14
#      Manual           26
# 2012 Automatic        14
#      Manual           28
# 2013 Automatic        82
#      Manual          114
#      Semi-Auto         8
# 2014 Automatic       144
#      Manual          190
#      Semi-Auto        18
# ...

# %%
data.groupby(['transmission', 'fuelType']).count()[['model']]
# Out:
#                        model
# transmission fuelType
# Automatic    Diesel       97
#              Hybrid     2038
#              Other       100
#              Petrol      422
# Manual       Diesel      378
#              Hybrid        4
#              Other         5
#              Petrol     3439
# Other        Hybrid        1
# Semi-Auto    Diesel       28
#              Petrol      226

# %%
data.query('year == 2015 and transmission == "Other"')
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 2458   Yaris  2015  12795        Other    16733   Hybrid    0  78.0
#
#       engineSize
# 2458         1.5

# %%
data['transmission'] = data['transmission'].replace('Other', 'Automatic')

# %%
data.groupby(['transmission', 'fuelType']).count()[['model']]
# Out:
#                        model
# transmission fuelType
# Automatic    Diesel       97
#              Hybrid     2039
#              Other       100
#              Petrol      422
# Manual       Diesel      378
#              Hybrid        4
#              Other         5
#              Petrol     3439
# Semi-Auto    Diesel       28
#              Petrol      226
